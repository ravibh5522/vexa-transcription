# %%
# !pip install pandas
# !pip install vexa-client
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.26.0 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# Successfully installed pandas-2.3.3 pytz-2025.2 tzdata-2025.2
# Collecting vexa-client
#   Downloading vexa_client-0.5.4-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: requests>=2.25.0 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from vexa-client) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from requests>=2.25.0->vexa-client) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from requests>=2.25.0->vexa-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from requests>=2.25.0->vexa-client) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ravi/Desktop/vexa/.venv/lib/python3.12/site-packages (from requests>=2.25.0->vexa-client) (2025.4.26)
# Downloading vexa_client-0.5.4-py3-none-any.whl (11 kB)
# Installing collected packages: vexa-client
# Successfully installed vexa-client-0.5.4

# %%
import os
import sys
import pandas as pd
from IPython.display import clear_output, display
import time
from dotenv import load_dotenv

load_dotenv()

# Add the testing directory to the path
sys.path.append('../testing')

from core import create_user_client, request_bot,get_transcript

from vexa_client.vexa import parse_url,VexaClient

BASE_URL=os.getenv('BASE_URL')
ADMIN_API_TOKEN = os.getenv('ADMIN_API_TOKEN')
TEST_USER_API_KEY = os.getenv('TEST_USER_API_KEY')

print(BASE_URL)

# %% [markdown]
# ### basic functionality test:
# 1. create user
# 2. set webhook (optional)
# 3. request bot
# 4. get meetings
# 5. get trasncript
# 6. update_bot_config
# 7. stop bot
# 8. delete_meeting

# %%
client = create_user_client(base_url=BASE_URL,admin_api_key=ADMIN_API_TOKEN)

# %%
#client = VexaClient(base_url=BASE_URL,api_key=TEST_USER_API_KEY)

# %%
client._api_key

# %%
#optional: set webhook
# obtain webhook url from https://webhook-test.com/

client.set_webhook_url("https://webhook-test.com/89d8111238baa40e7778559c7989cc60")

# webhook will be called with every bot status update

# %%
# create meeting with meet.new or in you MS Teams profile

# %%
# Google Meet:

meeting_url="https://meet.google.com/fov-ggxa-anx"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
#MS Teams:

meeting_url="https://teams.live.com/meet/93686988660257?p=MAjYtMwG3BT8kazbmo"
platform, native_meeting_id, passcode = parse_url(meeting_url)

# %%
client._api_key

# %%
request_bot(client,platform, native_meeting_id, passcode=passcode, bot_name="Vexa bot", language='en')


# # now admit the bot to the meeting

# %%
# speak and run this to see transcripts pooled for 10 seconds

get_transcript(client,platform, native_meeting_id,tail=50,duration=10)

# %%
client.stop_bot(platform=platform,native_meeting_id=native_meeting_id)

# %%
client.delete_meeting(platform=platform,native_meeting_id=native_meeting_id)

# %%
# after deletion transcripts removed from the database

get_transcript(client,platform, native_meeting_id,tail=50,duration=10)

# %%
# after deletion meeting record anonimized  


meetings = client.get_meetings()
meetings

# %%
client.stop_bot(platform='teams',native_meeting_id='93686988660257')

# %%
import pandas as pd

df = pd.DataFrame(meetings)

# %%
df[~df['status'].isin(['completed','failed'])]
